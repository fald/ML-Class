# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LeakyReLU
from tensorflow.keras.activations import linear, relu, sigmoid
# %matplotlib widget
from matplotlib.widgets import Slider
from lab_utils_common import dlc
from lab_utils_relu import *
from autils import plt_act_trio
import warnings
warnings.simplefilter(action='ignore', category=UserWarning)

# %%
plt_act_trio()
# Out:
# 2022-07-04 17:09:21.119935: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-07-04 17:09:21.120119: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-07-04 17:09:21.120709: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %% [markdown]
# Examples using a network of 1 hidden layer (units=3)

# %%
plt_relu_ex()
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …
# [<matplotlib.widgets.Slider at 0x7f940dc47160>,
#  <matplotlib.widgets.Slider at 0x7f94042704c0>,
#  <matplotlib.widgets.Slider at 0x7f94042682b0>,
#  <matplotlib.widgets.Slider at 0x7f9404279760>,
#  [<matplotlib.lines.Line2D at 0x7f940428cb80>,
#   <matplotlib.lines.Line2D at 0x7f940421b430>,
#   <matplotlib.lines.Line2D at 0x7f940421b6a0>,
#   <matplotlib.lines.Line2D at 0x7f940421b970>,
#   <matplotlib.lines.Line2D at 0x7f940421bbe0>]]

# %% [markdown]
# Mess around with the parameters above.
# Notice ReLU's non-linear behavior provides us the ability to turn off functions until they are needed.
